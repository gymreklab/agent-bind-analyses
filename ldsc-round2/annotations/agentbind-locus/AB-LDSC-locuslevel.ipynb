# %%
# %pylab inline
import pandas as pd
import numpy as np

for factor in ["Gata3", "Foxp3", "Stat3", "Tbet"]:
    scores = pd.read_csv("/storage/pandaman/project/AgentBind-LD/results/c/%s/lable-logit.txt"%factor, sep="\t",
                        names=["chrom","start","x","score"])

    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.hist(scores["score"], bins=50);
    ax.set_title(factor)
    print(factor)
    print(np.percentile(scores["score"], [95, 99, 100]))
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Gata3
# [0.272279  0.8445442 1.       ]
# Foxp3
# [0.952161 0.993313 0.999999]
# Stat3
# [0.734752 0.931633 1.      ]
# Tbet
# [1. 1. 1.]
